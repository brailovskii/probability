# %% [markdown]
# <a href="https://colab.research.google.com/github/brailovskii/probability/blob/main/Permutation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Question:
#
# In how many ways can 10 engineers and 4 doctors be seated at a round table if no two doctors sit together?

# %% [markdown]
# Solution:
#
# No two doctors sit together. Hence, let's initially arrange the 10 engineers at a round table. Number of ways in which this can be done
#
# = ( 10 − 1 )! = 9!  ...(A)
#
# Now there are 10 positions left (marked as *) to place the 4 doctors as shown below so that no two doctors can sit together.
#
# Number of ways in which this can be done
# = 10P4 ...(B)
#
# From (A) and (B),
# Required number of ways = 9! × 10P4
#
# ![image.png](data:image/png;base64,...)

# %%
from math import factorial

eng_num = 10 # number of engineers
doc_num = 4  # number of doctros

#Circular permutation for engineers
per_cir_eng = factorial(eng_num - 1)

#permutaion for doctorssf
per_doc = factorial(eng_num)/factorial(eng_num - doc_num)

tot_num_per = per_cir_eng * per_doc

print("Total number of permutaion is:", tot_num_per)
# Out:
# Total number of permutaion is: 1828915200.0

# %% [markdown]
# Source: https://www.careerbless.com/aptitude/qa/permutations_combinations24.php
